# %%
# # Query API devolver diccionaario con todos los datos de las tablas de la BD

# from sqlalchemy import create_engine, inspect, text
# import psycopg2
# import pandas as pd
# import json


# aws = config_json['aws']
# db_url = f'mysql+mysqlconnector://{aws["USER"]}:{aws["PASS"]}@{aws["HOST"]}:{aws["PORT"]}/desafio'
# engine = create_engine(db_url)

# # # traer tablas BD
# inspector = inspect(engine)
# table_names = inspector.get_table_names()

# # Bucle FOR
# dict_tables = {}
# for table in table_names:
#     dict_tables[table] = {}
#     try:
#         # query_1
#         query = f"""
#         SELECT * FROM {table}
#         """
#         with engine.connect() as connection:
#             database = connection.execute(text(query))

#         column_names = database.keys()

#         # Convertir los resultados en una lista de diccionarios
#         facilities_data = [dict(zip(column_names, row)) for row in database]

#         for dic in facilities_data:
#             filtered_dict = {key: value for key, value in dic.items() if key != 'id'}
#             dict_tables[table][dic['id']] = filtered_dict
#     except:
#         continue

# dict_tables
# Out:
# {'Amenities': {1: {'name': 'Amenity 1', 'createdAt': None, 'updatedAt': None},
#   2: {'name': 'Amenity 2', 'createdAt': None, 'updatedAt': None},
#   3: {'name': 'Amenity 3', 'createdAt': None, 'updatedAt': None},
#   4: {'name': 'Amenity 4', 'createdAt': None, 'updatedAt': None}},
#  'Contracted_services': {},
#  'EducationalCenter': {},
#  'EventUsers': {4: {'event_id': 3,
#    'user_id': 3,
#    'arriveTime': datetime.datetime(2023, 9, 25, 9, 26, 51),
#    'leaveTime': datetime.datetime(2023, 9, 25, 9, 26, 54),
#    'qrtoken': '123',
#    'createdAt': None,
#    'updatedAt': datetime.datetime(2023, 9, 25, 9, 26, 54)},
#   5: {'event_id': 4,
#    'user_id': 4,
#    'arriveTime': datetime.datetime(2023, 12, 20, 9, 30),
#    'leaveTime': datetime.datetime(2023, 12, 20, 11, 0),
#    'qrtoken': 'QR5',
#    'createdAt': None,
#    'updatedAt': None},
#   6: {'event_id': 5,
#    'user_id': 5,
#    'arriveTime': datetime.datetime(2024, 1, 10, 10, 15),
# ...

# %% [markdown]
# <BR>
#
# # CÓMO ELIMINAR TABLAS DE LA BASE DE DATOS

# %%
# from sqlalchemy.orm import sessionmaker

# Session = sessionmaker(bind=engine)
# session = Session()

# sql = f"DROP TABLE IF EXISTS {'Facilities'}"

# session.execute(text(sql))

# session.commit()  # Confirma los cambios en la base de datos
# session.close()

# %% [markdown]
# <BR>
#
# # ELIMINAR UNA COLUMNA DE LA BASE DE DATOS

# %%
# with engine.connect() as connection:
#     # Define la consulta SQL para eliminar la columna
#     query = "ALTER TABLE Users DROP COLUMN confirmed"
    
#     # Ejecuta la consulta
#     connection.execute(text(query))
    
#     # Confirma los cambios en la base de datos
#     connection.commit()

# # Cierra la conexión
# engine.dispose()

# %% [markdown]
# <br>
#
# # ELIMINAR FILAS DE UNA TABLA

# %%
# with engine.connect() as connection:
#     # Define la consulta SQL de eliminación
#     query = "DELETE FROM Facilities WHERE name = 'Angels'"
    
#     # Ejecuta la consulta
#     connection.execute(text(query))
    
#     # Confirma los cambios en la base de datos
#     connection.commit()

# # Cierra la conexión
# engine.dispose()

# %% [markdown]
# <br>
#
# # CÓMO AÑADIR COLUMNA

# %%
# from sqlalchemy import create_engine, text

# # Suponiendo que ya tienes la conexión a la base de datos configurada en 'engine'

# # SQL para agregar las nuevas columnas
# alter_table_sql = """
#     ALTER TABLE Users
#     ADD COLUMN area VARCHAR(255)
# """

# # Ejecuta la consulta para agregar las columnas
# with engine.connect() as connection:
#     connection.execute(text(alter_table_sql))

# %% [markdown]
# <br>
#
# # CÓMO MODIFICAR EL NOMBRE DE LAS COLUMNAS DE UNA TABLA

# %%
# with engine.connect() as connection:
#     # Define la consulta SQL para modificar el nombre de la columna
#     query = "ALTER TABLE Events CHANGE Name name VARCHAR(255)"
    
#     # Ejecuta la consulta
#     connection.execute(text(query))
    
#     # Confirma los cambios en la base de datos
#     connection.commit()

# # Cierra la conexión
# engine.dispose()

# %% [markdown]
# <br>
#
# # CÓMO MODIFICAR EL ORDEN DE LAS COLUMNAS

# %%
# from sqlalchemy import create_engine, text

# # Suponiendo que ya tienes la conexión a la base de datos configurada en 'engine'

# # SQL para cambiar el orden de las columnas
# alter_table_sql = """
#     ALTER TABLE Users
#     MODIFY COLUMN area VARCHAR(255) AFTER responsability
# """

# # Ejecuta la consulta para cambiar el orden de las columnas
# with engine.connect() as connection:
#     connection.execute(text(alter_table_sql))

# %% [markdown]
# <br>
#
# # CÓMO ELIMINAR TODOS LOS DATOS DE LA TABLA Y RESETEAR EL VALOR AUTOINCREMENTAL A UN VALOR ESPECÍFICO

# %%
# from sqlalchemy import create_engine, text

# # Suponiendo que ya tienes la conexión a la base de datos configurada en 'engine'

# # Define la consulta SQL para restablecer el valor autoincremental y eliminar todos los datos de la tabla
# query_delete = "DELETE FROM Facilities;"
# query_alter = "ALTER TABLE Facilities AUTO_INCREMENT = 0;"

# # Ejecuta la consulta
# with engine.connect() as connection:
#     # Paso 1: Eliminar todos los datos existentes en la tabla
#     connection.execute(text(query_delete))
    
#     # Paso 2: Modificar la definición de la tabla para reiniciar el valor autoincremental
#     connection.execute(text(query_alter))

# %% [markdown]
# <br>
#
# # CÓMO ELIMINAR TODOS LOS DATOS EXISTENTES DE LA TABLA

# %%
# from sqlalchemy import create_engine, text

# # Suponiendo que ya tienes la conexión a la base de datos configurada en 'engine'

# # Define la consulta SQL para restablecer el valor autoincremental
# query = "TRUNCATE TABLE tu_tabla;"

# # Ejecuta la consulta
# with engine.connect() as connection:
#     connection.execute(text(query))

# %% [markdown]
# # Hacer una llamada a columnas concretas dependiendo de una entrada (SELECT - FROM - WHERE)

# %%
# # Crea una sesión de SQLAlchemy
# Session = sessionmaker(bind=engine)
# session = Session()

# query = """
# SELECT dateTime, speacker, description, title, location_id FROM Events WHERE Title = 'Evento 4'
# """

# with session:
#     # Ejecuta la consulta para leer la tabla Facilities
#     database = session.execute(text(query))
#     columnas = database.keys()

#     # Recupera los resultados
#     facilities_data = database.fetchall()

# # Imprime los resultados
# dict_table = {}
# for row in facilities_data:
#     dict_table['title'] = row[3]
#     dict_table['description'] = row[2]
#     dict_table['speacker'] = row[1]
#     dict_table['day'] = pd.to_datetime(row[0], yearfirst=True).day_name()
#     dict_table['month'] = pd.to_datetime(row[0], yearfirst=True).month_name()
#     print(row)

# dict_table
